# %% [markdown]
# ### The nsmallest and nlargest methods
# * The **nlargest** method returns a specified number of rows with the largest values from a given column.
# * The **nsmallest** method returns rows with the smallest values from a given column.
# * The **nlargest** and **nsmallest** methods are more efficient than sorting the entire **DataFrame**.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv", index_col="ID").sort_index()

# %%
dataframe.head()
# Out:
#       Case Number              Date                 Block IUCR Primary Type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26630    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26682    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                Description Location Description  Arrest  Domestic  Beat  ...  \
# ID                                                                       ...
# 26595  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26596  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26630  FIRST DEGREE MURDER          PARKING LOT    True     False  2223  ...
# 26667  FIRST DEGREE MURDER               STREET    True     False   333  ...
# ...

# %%
# Retrieve the 4 Beat with the highest/largest box office gross
dataframe.sort_values("Beat", ascending=False).head(4)
# Out:
#          Case Number             Date                   Block  IUCR  \
# ID
# 12763554    JF320550   7/17/2022 2:00      012XX N HAMLIN AVE   820
# 13475933    JH282116   2/20/2022 0:00  018XX N MONTICELLO AVE  1754
# 12598922    JF120532   1/22/2022 5:00       037XX W GRAND AVE  031A
# 12605582    JF129082  1/30/2022 20:59     039XX W DIVISION ST  2024
#
#                         Primary Type  \
# ID
# 12763554                       THEFT
# 13475933  OFFENSE INVOLVING CHILDREN
# 12598922                     ROBBERY
# 12605582                   NARCOTICS
#
#                                                 Description  \
# ID
# 12763554                                     $500 AND UNDER
# 13475933  AGGRAVATED SEXUAL ASSAULT OF CHILD BY FAMILY M...
# 12598922                                    ARMED - HANDGUN
# 12605582                           POSSESS - HEROIN (WHITE)
#
#             Location Description  Arrest  Domestic  Beat  ...  Ward  \
# ...

# %%
dataframe.nlargest(n=4, columns="Beat")
# Out:
#          Case Number              Date                   Block  IUCR  \
# ID
# 12581840    JF100105  01-01-2022 00:01  018XX N MONTICELLO AVE  1310
# 12581857    JF100075  01-01-2022 01:00     015XX N HARDING AVE   560
# 12581931    JF100178  01-01-2022 03:30     039XX W DIVISION ST   460
# 12582826    JF101211  01-02-2022 11:35       037XX W NORTH AVE  1477
#
#                Primary Type                 Description  \
# ID
# 12581840    CRIMINAL DAMAGE                 TO PROPERTY
# 12581857            ASSAULT                      SIMPLE
# 12581931            BATTERY                      SIMPLE
# 12582826  WEAPONS VIOLATION  RECKLESS FIREARM DISCHARGE
#
#                             Location Description  Arrest  Domestic  Beat  ...  \
# ID                                                                        ...
# 12581840                               APARTMENT   False     False  2535  ...
# 12581857                               APARTMENT    True      True  2535  ...
# ...

# %%
dataframe["Beat"].nlargest(4)
# Out:
# ID
# 12581840    2535
# 12581857    2535
# 12581931    2535
# 12582826    2535
# Name: Beat, dtype: int64

# %%
dataframe.nsmallest(4, columns="Beat")
# Out:
#          Case Number              Date                 Block IUCR  \
# ID
# 12582254    JF100514  01-01-2022 11:36   0000X W RANDOLPH ST  486
# 12582674    JF100952  01-01-2022 13:57  002XX N MICHIGAN AVE  870
# 12582678    JF100964  01-02-2022 02:05      001XX N STATE ST  320
# 12583650    JF102181  01-03-2022 12:20      001XX N STATE ST  860
#
#          Primary Type              Description Location Description  Arrest  \
# ID
# 12582254      BATTERY  DOMESTIC BATTERY SIMPLE            APARTMENT   False
# 12582674        THEFT           POCKET-PICKING        HOTEL / MOTEL   False
# 12582678      ROBBERY   STRONG ARM - NO WEAPON         CTA PLATFORM   False
# 12583650        THEFT             RETAIL THEFT   SMALL RETAIL STORE   False
#
#           Domestic  Beat  ...  Ward  Community Area  FBI Code X Coordinate  \
# ID                        ...
# 12582254      True   111  ...  42.0              32       08B    1176102.0
# ...

# %%
dataframe["Beat"].nsmallest(4)
# Out:
# ID
# 12582254    111
# 12582674    111
# 12582678    111
# 12583650    111
# Name: Beat, dtype: int64
