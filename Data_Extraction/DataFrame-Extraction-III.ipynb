# %% [markdown]
# ### Retrieve row by index label with loc accessor
# * The **loc** accessor retrieves one or more rows by index label.
# * Provide a pair of square brackets after the accessor.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv")

# %%
dataframe = dataframe.set_index('ID')

# %%
dataframe.loc[12592454]
# Out:
# Case Number                                   JF113025
# Date                                   1/14/2022 15:55
# Block                                067XX S MORGAN ST
# IUCR                                              2826
# Primary Type                             OTHER OFFENSE
# Description             HARASSMENT BY ELECTRONIC MEANS
# Location Description                         RESIDENCE
# Arrest                                           False
# Domestic                                          True
# Beat                                               724
# District                                             7
# Ward                                              16.0
# Community Area                                      68
# FBI Code                                            26
# X Coordinate                                 1170805.0
# Y Coordinate                                 1860170.0
# Year                                              2022
# ...

# %%
dataframe.loc[[12592454, 12785595]]
dataframe.loc[[12785595, 12592454]]
# Out:
#          Case Number              Date                   Block  IUCR  \
# ID
# 12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
#
#            Primary Type                     Description Location Description  \
# ID
# 12785595    SEX OFFENSE  SEXUAL EXPLOITATION OF A CHILD            APARTMENT
# 12592454  OTHER OFFENSE  HARASSMENT BY ELECTRONIC MEANS            RESIDENCE
#
#           Arrest  Domestic  Beat  ...  Ward  Community Area  FBI Code  \
# ID                                ...
# 12785595    True     False   324  ...   5.0              69        17
# 12592454   False      True   724  ...  16.0              68        26
#
#          X Coordinate  Y Coordinate  Year       Updated On   Latitude  \
# ID
# 12785595    1185135.0     1857211.0  2022  9/14/2023 15:41  41.763338
# 12592454    1170805.0     1860170.0  2022  9/14/2023 15:41  41.771782
#
# ...

# %%
dataframe.loc[12592454: 12888104]
# Out:
#          Case Number              Date                   Block  IUCR  \
# ID
# 12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
#
#                Primary Type                       Description  \
# ID
# 12592454      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS
# 12785595        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD
# 12808281        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 12888104  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE
#
#          Location Description  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                     ...
# 12592454            RESIDENCE   False      True   724  ...  16.0
# 12785595            APARTMENT    True     False   324  ...   5.0
# ...

# %%
# If the index position is in reverse, it won't give any result
dataframe.loc[12888104: 12592454]
# Out:
# Empty DataFrame
# Columns: [Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 21 columns]

# %%
dataframe.loc[12827191:]
# Out:
#          Case Number             Date               Block  IUCR  \
# ID
# 12827191    JF395031  9/13/2022 20:32     025XX W 72ND ST  1320
# 12776992    JF336641  7/29/2022 19:30  081XX S COLFAX AVE   498
#
#              Primary Type                                        Description  \
# ID
# 12827191  CRIMINAL DAMAGE                                         TO VEHICLE
# 12776992          BATTERY  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...
#
#          Location Description  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                     ...
# 12827191               STREET   False      True   832  ...  18.0
# 12776992               STREET   False      True   422  ...   7.0
#
#           Community Area  FBI Code X Coordinate  Y Coordinate  Year  \
# ID
# 12827191              66        14    1160781.0     1856827.0  2022
# 12776992              46       04B    1194924.0     1851513.0  2022
#
#                 Updated On   Latitude  Longitude  \
# ...

# %%
dataframe.loc[:12888104]
# Out:
#          Case Number              Date                   Block  IUCR  \
# ID
# 12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
#
#                Primary Type                       Description  \
# ID
# 12592454      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS
# 12785595        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD
# 12808281        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 12888104  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE
#
#          Location Description  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                     ...
# 12592454            RESIDENCE   False      True   724  ...  16.0
# 12785595            APARTMENT    True     False   324  ...   5.0
# ...
