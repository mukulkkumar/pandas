# %% [markdown]
# ### Rename index labels or columns in a dataframe
# * The **rename** method accepts a dictionary for either its **columns** or **index** parameters.
# * The dictionary keys represent the existing names and the values represent the new names.
# * We can replace all columns by overwriting the **DataFrame's** columns attribute.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv", index_col="ID").sort_index()

# %%
dataframe.head()
# Out:
#       Case Number              Date                 Block IUCR Primary Type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26630    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26682    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                Description Location Description  Arrest  Domestic  Beat  ...  \
# ID                                                                       ...
# 26595  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26596  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26630  FIRST DEGREE MURDER          PARKING LOT    True     False  2223  ...
# 26667  FIRST DEGREE MURDER               STREET    True     False   333  ...
# ...

# %%
dataframe = dataframe.rename(columns={"Location Description": "Location", "Community Area": "Area"})

# %%
dataframe.head()
# Out:
#       Case Number              Date                 Block IUCR Primary Type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26630    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26682    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                Description     Location  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                               ...
# 26595  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26596  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26630  FIRST DEGREE MURDER  PARKING LOT    True     False  2223  ...  21.0
# 26667  FIRST DEGREE MURDER       STREET    True     False   333  ...   7.0
# ...

# %%
swaps = {
    26630: 26650,
    26667: 26667,
    26682: 26623
}

dataframe = dataframe.rename(index=swaps)

# %%
dataframe.head()
# Out:
#       Case Number              Date                 Block IUCR Primary Type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26650    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26623    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                Description     Location  Arrest  Domestic  Beat  ...  Ward  \
# ID                                                               ...
# 26595  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26596  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26650  FIRST DEGREE MURDER  PARKING LOT    True     False  2223  ...  21.0
# 26667  FIRST DEGREE MURDER       STREET    True     False   333  ...   7.0
# ...

# %%
dataframe.columns.values
# Out:
# array(['Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'], dtype=object)

# %%
dataframe.columns = ['case_number', 'date', 'block', 'iucr', 'primary_type',
       'description', 'location', 'arrest', 'domestic', 'beat',
       'district', 'ward', 'area', 'fbi_code', 'x_coordinate',
       'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
       'location']

# %%
dataframe.head()
# Out:
#       case_number              date                 block iucr primary_type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26650    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26623    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                description     location  arrest  domestic  beat  ...  ward  \
# ID                                                               ...
# 26595  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26596  FIRST DEGREE MURDER       STREET    True     False   624  ...   8.0
# 26650  FIRST DEGREE MURDER  PARKING LOT    True     False  2223  ...  21.0
# 26667  FIRST DEGREE MURDER       STREET    True     False   333  ...   7.0
# ...
