# %% [markdown]
# ### Retrieve rows by index position with iloc accessor
# * The **iloc** accessor retrieves one or more rows by index position.
# * Provide a pair of square brackets after the accessor.
# * **iloc** accepts single values, list and slices.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv")

# %%
dataframe.head()
# Out:
#          ID Case Number              Date                   Block  IUCR  \
# 0  12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 1  12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 2  12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 3  12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
# 4  13209277    JG422539    8/15/2022 9:00    0000X W JACKSON BLVD   810
#
#         Primary Type                       Description  \
# 0      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS
# 1        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD
# 2        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 3  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE
# 4              THEFT                         OVER $500
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                     RESIDENCE   False      True  ...  16.0              68
# 1                     APARTMENT    True     False  ...   5.0              69
# 2                     RESIDENCE   False     False  ...  39.0              11
# 3                        STREET   False     False  ...  17.0              68
# 4  COMMERCIAL / BUSINESS OFFICE   False     False  ...   4.0              32
#
#    FBI Code  X Coordinate Y Coordinate  Year       Updated On   Latitude  \
# 0        26     1170805.0    1860170.0  2022  9/14/2023 15:41  41.771782
# 1        17     1185135.0    1857211.0  2022  9/14/2023 15:41  41.763338
# 2        17     1138383.0    1937953.0  2022  9/14/2023 15:41  41.985875
# 3        15     1169903.0    1856822.0  2022  9/14/2023 15:41  41.762615
# 4         6           NaN          NaN  2022  9/14/2023 15:43        NaN
#
#    Longitude                       Location
# 0 -87.649437  (41.771782439, -87.649436929)
# 1 -87.597001  (41.763337967, -87.597001131)
# 2 -87.766404  (41.985875279, -87.766403857)
# 3 -87.652840   (41.76261474, -87.652840463)
# 4        NaN                            NaN
#
# [5 rows x 22 columns]

# %%
dataframe.iloc[2]
# Out:
# ID                                              12808281
# Case Number                                     JF373517
# Date                                     8/14/2022 14:00
# Block                                055XX W ARDMORE AVE
# IUCR                                                1562
# Primary Type                                 SEX OFFENSE
# Description             AGGRAVATED CRIMINAL SEXUAL ABUSE
# Location Description                           RESIDENCE
# Arrest                                             False
# Domestic                                           False
# Beat                                                1621
# District                                              16
# Ward                                                39.0
# Community Area                                        11
# FBI Code                                              17
# X Coordinate                                   1138383.0
# Y Coordinate                                   1937953.0
# Year                                                2022
# Updated On                               9/14/2023 15:41
# Latitude                                       41.985875
# Longitude                                     -87.766404
# Location                   (41.985875279, -87.766403857)
# Name: 2, dtype: object

# %%
dataframe.iloc[[2,5]]
# Out:
#          ID Case Number             Date                  Block  IUCR  \
# 2  12808281    JF373517  8/14/2022 14:00    055XX W ARDMORE AVE  1562
# 5  12622465    JF149923  2/19/2022 10:36  010XX N FRANCISCO AVE   486
#
#   Primary Type                       Description         Location Description  \
# 2  SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE                    RESIDENCE
# 5      BATTERY           DOMESTIC BATTERY SIMPLE  HOSPITAL BUILDING / GROUNDS
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 2   False     False  ...  39.0              11        17     1138383.0
# 5    True      True  ...  26.0              24       08B     1156861.0
#
#   Y Coordinate  Year       Updated On   Latitude  Longitude  \
# 2    1937953.0  2022  9/14/2023 15:41  41.985875 -87.766404
# 5    1906972.0  2022  9/15/2023 15:41  41.900506 -87.699285
#
#                         Location
# 2  (41.985875279, -87.766403857)
# 5  (41.900505589, -87.699285044)
#
# [2 rows x 22 columns]

# %%
dataframe.iloc[3:5]
# Out:
#          ID Case Number              Date                 Block  IUCR  \
# 3  12888104    JF469015  11-10-2022 03:47        072XX S MAY ST  1477
# 4  13209277    JG422539    8/15/2022 9:00  0000X W JACKSON BLVD   810
#
#         Primary Type                 Description  \
# 3  WEAPONS VIOLATION  RECKLESS FIREARM DISCHARGE
# 4              THEFT                   OVER $500
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 3                        STREET   False     False  ...  17.0              68
# 4  COMMERCIAL / BUSINESS OFFICE   False     False  ...   4.0              32
#
#    FBI Code  X Coordinate Y Coordinate  Year       Updated On   Latitude  \
# 3        15     1169903.0    1856822.0  2022  9/14/2023 15:41  41.762615
# 4         6           NaN          NaN  2022  9/14/2023 15:43        NaN
#
#   Longitude                      Location
# 3 -87.65284  (41.76261474, -87.652840463)
# 4       NaN                           NaN
#
# [2 rows x 22 columns]

# %%
dataframe.iloc[0:4]
# Out:
#          ID Case Number              Date                   Block  IUCR  \
# 0  12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 1  12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 2  12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 3  12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
#
#         Primary Type                       Description Location Description  \
# 0      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS            RESIDENCE
# 1        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD            APARTMENT
# 2        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE            RESIDENCE
# 3  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE               STREET
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False      True  ...  16.0              68        26     1170805.0
# 1    True     False  ...   5.0              69        17     1185135.0
# 2   False     False  ...  39.0              11        17     1138383.0
# 3   False     False  ...  17.0              68        15     1169903.0
#
#   Y Coordinate  Year       Updated On   Latitude  Longitude  \
# 0    1860170.0  2022  9/14/2023 15:41  41.771782 -87.649437
# 1    1857211.0  2022  9/14/2023 15:41  41.763338 -87.597001
# 2    1937953.0  2022  9/14/2023 15:41  41.985875 -87.766404
# 3    1856822.0  2022  9/14/2023 15:41  41.762615 -87.652840
#
#                         Location
# 0  (41.771782439, -87.649436929)
# 1  (41.763337967, -87.597001131)
# 2  (41.985875279, -87.766403857)
# 3   (41.76261474, -87.652840463)
#
# [4 rows x 22 columns]

# %%
dataframe.iloc[:4]
# Out:
#          ID Case Number              Date                   Block  IUCR  \
# 0  12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 1  12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 2  12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 3  12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
#
#         Primary Type                       Description Location Description  \
# 0      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS            RESIDENCE
# 1        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD            APARTMENT
# 2        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE            RESIDENCE
# 3  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE               STREET
#
#    Arrest  Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# 0   False      True  ...  16.0              68        26     1170805.0
# 1    True     False  ...   5.0              69        17     1185135.0
# 2   False     False  ...  39.0              11        17     1138383.0
# 3   False     False  ...  17.0              68        15     1169903.0
#
#   Y Coordinate  Year       Updated On   Latitude  Longitude  \
# 0    1860170.0  2022  9/14/2023 15:41  41.771782 -87.649437
# 1    1857211.0  2022  9/14/2023 15:41  41.763338 -87.597001
# 2    1937953.0  2022  9/14/2023 15:41  41.985875 -87.766404
# 3    1856822.0  2022  9/14/2023 15:41  41.762615 -87.652840
#
#                         Location
# 0  (41.771782439, -87.649436929)
# 1  (41.763337967, -87.597001131)
# 2  (41.985875279, -87.766403857)
# 3   (41.76261474, -87.652840463)
#
# [4 rows x 22 columns]

# %%
len(dataframe)
# Out:
# 45423

# %%
dataframe.iloc[45420:]
# Out:
#              ID Case Number             Date               Block  IUCR  \
# 45420  12746732    JF299968  6/30/2022 13:08  071XX S HALSTED ST  143A
# 45421  12827191    JF395031  9/13/2022 20:32     025XX W 72ND ST  1320
# 45422  12776992    JF336641  7/29/2022 19:30  081XX S COLFAX AVE   498
#
#             Primary Type                                        Description  \
# 45420  WEAPONS VIOLATION                      UNLAWFUL POSSESSION - HANDGUN
# 45421    CRIMINAL DAMAGE                                         TO VEHICLE
# 45422            BATTERY  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...
#
#       Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 45420          GAS STATION    True     False  ...   6.0              68
# 45421               STREET   False      True  ...  18.0              66
# 45422               STREET   False      True  ...   7.0              46
#
#        FBI Code  X Coordinate Y Coordinate  Year        Updated On   Latitude  \
# 45420        15     1172199.0    1857618.0  2022  01-03-2023 15:40  41.764749
# 45421        14     1160781.0    1856827.0  2022  01-03-2023 15:40  41.762822
# 45422       04B     1194924.0    1851513.0  2022  01-03-2023 15:40  41.747467
#
#        Longitude                       Location
# 45420 -87.644402  (41.764748911, -87.644401916)
# 45421 -87.686274  (41.762821622, -87.686274014)
# 45422 -87.561311  (41.747466676, -87.561310599)
#
# [3 rows x 22 columns]
