# %% [markdown]
# ### The drop_duplicates method
# * The **drop_duplicates** method delete rows with duplicate values.
# * By default, it will remove a row if all of its values are shared with another row.
# * The **subset** parameter configures the columns to look for duplicate values within.
# * Pass a list to **subset** parameter to look fr duplicates across multiple columns.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("Crime Prediction in Chicago_Dataset.csv")

# %%
dataframe.drop_duplicates()

dataframe.drop_duplicates('Primary Type')

dataframe.drop_duplicates('Primary Type', keep="first")

dataframe.drop_duplicates('Primary Type', keep="last")

dataframe.drop_duplicates('Primary Type', keep=False)
# Out:
#              ID Case Number              Date                Block  IUCR  \
# 39021  12669127    JF206171  04-12-2022 22:27  011XX N LARRABEE ST  1481
# 44563  12731836    JF281839   6/16/2022 11:22     0000X E 111TH ST  1536
#
#            Primary Type                         Description  \
# 39021      NON-CRIMINAL  CONCEALED CARRY LICENSE REVOCATION
# 44563  PUBLIC INDECENCY                    LICENSED PREMISE
#
#                         Location Description  Arrest  Domestic  ...  Ward  \
# 39021  POLICE FACILITY / VEHICLE PARKING LOT    True     False  ...  27.0
# 44563                             RESTAURANT    True     False  ...   9.0
#
#        Community Area  FBI Code  X Coordinate Y Coordinate  Year  \
# 39021               8        15     1172122.0    1908040.0  2022
# 44563              49        17     1178327.0    1831371.0  2022
#
#              Updated On   Latitude  Longitude                       Location
# ...

# %%
dataframe.drop_duplicates(["Primary Type", "Location Description"]).sort_values('Primary Type')

dataframe.drop_duplicates(["Primary Type", "Location Description"], keep="last").sort_values('Primary Type')
# Out:
#              ID Case Number              Date                   Block  IUCR  \
# 26684  12583120    JF100217  01-01-2022 03:58     090XX S ASHLAND AVE  1020
# 22874  12583157    JF100818  01-01-2022 19:15         003XX W 79TH ST  1020
# 31756  12622813    JF150257    2/20/2022 9:37  008XX W WELLINGTON AVE  1090
# 2511   12744064    JF296803    6/28/2022 2:20      001XX S CLINTON ST  1020
# 44508  12815306    JF381829  09-03-2022 16:18       072XX S UNION AVE  1025
# ...         ...         ...               ...                     ...   ...
# 32218  12589872    JF109871  01-11-2022 18:18         026XX E 76TH ST  143A
# 6506   12599996    JF122055   1/23/2022 18:30       023XX N MOODY AVE  1477
# 41520  12660271    JF195421  04-03-2022 04:07    071XX S EXCHANGE AVE  1477
# 41630  12753517    JF308340  07-03-2022 00:55        015XX N WELLS ST  1477
# 33846  12783650    JF344431  08-03-2022 05:30     081XX S WESTERN AVE  143A
#
# ...
