# %% [markdown]
# ### The split method
# * The **str.split** method splits a string by the occurence of a delimiter. Pandas returns a **Series** of lists.
# * Use the **str.get** method to access a nested list element by its index position.
# * The **expand** parameter returns a **DataFrame** instead of a **Series** of lists.
# * The **n** parameter limits the number of splits.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv", index_col="ID").sort_index()

# %%
dataframe.head()
# Out:
#       Case Number              Date                 Block IUCR Primary Type  \
# ID
# 26595    JF130370  02-01-2022 07:15       009XX E 79TH ST  110     HOMICIDE
# 26596    JF130370  02-01-2022 06:54       009XX E 79TH ST  110     HOMICIDE
# 26630    JF154557   2/24/2022 12:05    097XX S HALSTED ST  110     HOMICIDE
# 26667    JF183032   3/22/2022 22:29       019XX E 73RD PL  110     HOMICIDE
# 26682    JF193651  04-01-2022 13:49  008XX N LECLAIRE AVE  110     HOMICIDE
#
#                Description Location Description  Arrest  Domestic  Beat  ...  \
# ID                                                                       ...
# 26595  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26596  FIRST DEGREE MURDER               STREET    True     False   624  ...
# 26630  FIRST DEGREE MURDER          PARKING LOT    True     False  2223  ...
# 26667  FIRST DEGREE MURDER               STREET    True     False   333  ...
# ...

# %%
dataframe['Description'].str.split(" ")
# Out:
# ID
# 26595                              [FIRST, DEGREE, MURDER]
# 26596                              [FIRST, DEGREE, MURDER]
# 26630                              [FIRST, DEGREE, MURDER]
# 26667                              [FIRST, DEGREE, MURDER]
# 26682                              [FIRST, DEGREE, MURDER]
#                                  ...
# 13627481        [FINANCIAL, IDENTITY, THEFT, OVER, $, 300]
# 13627576        [FINANCIAL, IDENTITY, THEFT, OVER, $, 300]
# 13627896    [FINANCIAL, IDENTITY, THEFT, $300, AND, UNDER]
# 13629868                                  [NON-AGGRAVATED]
# 13630511    [FINANCIAL, IDENTITY, THEFT, $300, AND, UNDER]
# Name: Description, Length: 45423, dtype: object

# %%
dataframe['Description'].str.split(" ").str.get(0)
# Out:
# ID
# 26595                FIRST
# 26596                FIRST
# 26630                FIRST
# 26667                FIRST
# 26682                FIRST
#                  ...
# 13627481         FINANCIAL
# 13627576         FINANCIAL
# 13627896         FINANCIAL
# 13629868    NON-AGGRAVATED
# 13630511         FINANCIAL
# Name: Description, Length: 45423, dtype: object

# %%
dataframe['Description'].str.split(" ", expand=True)
# Out:
#                        0         1       2     3     4      5     6     7  \
# ID
# 26595              FIRST    DEGREE  MURDER  None  None   None  None  None
# 26596              FIRST    DEGREE  MURDER  None  None   None  None  None
# 26630              FIRST    DEGREE  MURDER  None  None   None  None  None
# 26667              FIRST    DEGREE  MURDER  None  None   None  None  None
# 26682              FIRST    DEGREE  MURDER  None  None   None  None  None
# ...                  ...       ...     ...   ...   ...    ...   ...   ...
# 13627481       FINANCIAL  IDENTITY   THEFT  OVER     $    300  None  None
# 13627576       FINANCIAL  IDENTITY   THEFT  OVER     $    300  None  None
# 13627896       FINANCIAL  IDENTITY   THEFT  $300   AND  UNDER  None  None
# 13629868  NON-AGGRAVATED      None    None  None  None   None  None  None
# 13630511       FINANCIAL  IDENTITY   THEFT  $300   AND  UNDER  None  None
#
#              8     9
# ID
# 26595     None  None
# 26596     None  None
# ...

# %%
dataframe['Description'].str.split(" ", expand=True, n=2)
# Out:
#                        0         1                     2
# ID
# 26595              FIRST    DEGREE                MURDER
# 26596              FIRST    DEGREE                MURDER
# 26630              FIRST    DEGREE                MURDER
# 26667              FIRST    DEGREE                MURDER
# 26682              FIRST    DEGREE                MURDER
# ...                  ...       ...                   ...
# 13627481       FINANCIAL  IDENTITY      THEFT OVER $ 300
# 13627576       FINANCIAL  IDENTITY      THEFT OVER $ 300
# 13627896       FINANCIAL  IDENTITY  THEFT $300 AND UNDER
# 13629868  NON-AGGRAVATED      None                  None
# 13630511       FINANCIAL  IDENTITY  THEFT $300 AND UNDER
#
# [45423 rows x 3 columns]
