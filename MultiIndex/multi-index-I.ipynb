# %% [markdown]
# ### Create a MultiIndex
# * A **MultiIndex** is an index with multiple levels or layers.
# * Pass the **set_index** method a list of column names to create a multi-index **DataFrame**.
# * The order of the list's values will determine the order of the levels.
# * Alternatively, we can pass the **read_csv** function's **index_col** parameter a list of columns.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv")

# %%
dataframe.head()
# Out:
#          ID Case Number              Date                   Block  IUCR  \
# 0  12592454    JF113025   1/14/2022 15:55       067XX S MORGAN ST  2826
# 1  12785595    JF346553  08-05-2022 21:00  072XX S UNIVERSITY AVE  1544
# 2  12808281    JF373517   8/14/2022 14:00     055XX W ARDMORE AVE  1562
# 3  12888104    JF469015  11-10-2022 03:47          072XX S MAY ST  1477
# 4  13209277    JG422539    8/15/2022 9:00    0000X W JACKSON BLVD   810
#
#         Primary Type                       Description  \
# 0      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS
# 1        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD
# 2        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 3  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE
# 4              THEFT                         OVER $500
#
#            Location Description  Arrest  Domestic  ...  Ward  Community Area  \
# 0                     RESIDENCE   False      True  ...  16.0              68
# ...

# %%
dataframe.nunique()
# Out:
# ID                      45423
# Case Number             45419
# Date                    28199
# Block                   16626
# IUCR                      270
# Primary Type               31
# Description               251
# Location Description      107
# Arrest                      2
# Domestic                    2
# Beat                      274
# District                   23
# Ward                       50
# Community Area             77
# FBI Code                   26
# X Coordinate            23500
# Y Coordinate            26561
# Year                        1
# Updated On                954
# Latitude                31718
# Longitude               31714
# Location                31732
# dtype: int64

# %%
new_df = dataframe.set_index(keys=["District", "Primary Type"]).sort_index()

# %%
new_df.head()
# Out:
#                              ID Case Number              Date  \
# District Primary Type
# 1        ARSON         12744064    JF296803    6/28/2022 2:20
#          ARSON         12631318    JF160624  03-02-2022 08:40
#          ARSON         12782929    JF343543  08-04-2022 03:51
#          ASSAULT       12929458    JF518533  12/21/2022 10:15
#          ASSAULT       12905051    JF489349  11/27/2022 11:46
#
#                                           Block  IUCR Description  \
# District Primary Type
# 1        ARSON               001XX S CLINTON ST  1020     BY FIRE
#          ARSON                006XX S HOLDEN CT  1020     BY FIRE
#          ARSON                 010XX S WELLS ST  1020     BY FIRE
#          ASSAULT       014XX S MUSEUM CAMPUS DR   560      SIMPLE
#          ASSAULT          0000X E CONGRESS PKWY   560      SIMPLE
#
#                                Location Description  Arrest  Domestic  Beat  \
# District Primary Type
# ...

# %%
df = pd.read_csv("../Crime Prediction in Chicago_Dataset.csv", index_col=["District", "Primary Type"]).sort_index()

# %%
df.head()
# Out:
#                              ID Case Number              Date  \
# District Primary Type
# 1        ARSON         12744064    JF296803    6/28/2022 2:20
#          ARSON         12631318    JF160624  03-02-2022 08:40
#          ARSON         12782929    JF343543  08-04-2022 03:51
#          ASSAULT       12929458    JF518533  12/21/2022 10:15
#          ASSAULT       12905051    JF489349  11/27/2022 11:46
#
#                                           Block  IUCR Description  \
# District Primary Type
# 1        ARSON               001XX S CLINTON ST  1020     BY FIRE
#          ARSON                006XX S HOLDEN CT  1020     BY FIRE
#          ARSON                 010XX S WELLS ST  1020     BY FIRE
#          ASSAULT       014XX S MUSEUM CAMPUS DR   560      SIMPLE
#          ASSAULT          0000X E CONGRESS PKWY   560      SIMPLE
#
#                                Location Description  Arrest  Domestic  Beat  \
# District Primary Type
# ...

# %%
df.index
# Out:
# MultiIndex([( 1,              'ARSON'),
#             ( 1,              'ARSON'),
#             ( 1,              'ARSON'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ( 1,            'ASSAULT'),
#             ...
#             (25,  'WEAPONS VIOLATION'),
#             (25,  'WEAPONS VIOLATION'),
#             (25,  'WEAPONS VIOLATION'),
#             (25,  'WEAPONS VIOLATION'),
#             (25,  'WEAPONS VIOLATION'),
#             (25,  'WEAPONS VIOLATION'),
#             (31,            'BATTERY'),
#             (31,  'CRIMINAL TRESPASS'),
#             (31, 'DECEPTIVE PRACTICE'),
#             (31,              'THEFT')],
#            names=['District', 'Primary Type'], length=45423)
